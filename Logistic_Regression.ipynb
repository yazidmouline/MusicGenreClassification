# %%
import numpy as np
from numpy import linalg
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.mixture import GaussianMixture
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

import pandas as pd
import numpy as np
import utils
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt

# %%
#importing our dataset and spliting into training and testing set

genres_df = pd.read_csv('../MusicGenreClassification/Music_data_set_2genres.csv')

x = genres_df.drop(['Unnamed: 0', 'song', 'genre', 'genre_binary'], axis=1)
y = genres_df['genre']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 27) 

print(genres_df.dtypes)     # Prints out the data types associated to each of the fields in the table
genres_df.head()
# Out:
# Unnamed: 0            int64
# song                 object
# mean_mfccs          float64
# mean_chroma_stft    float64
# tempo               float64
# pulse               float64
# flatness            float64
# contrast            float64
# zero_crossing         int64
# genre                object
# genre_binary          int64
# dtype: object
#    Unnamed: 0             song  mean_mfccs  mean_chroma_stft       tempo  \
# 0           0  blues.00000.wav    1.938016          0.350088  123.046875
# 1           1  blues.00001.wav   -0.055611          0.340914  107.666016
# 2           2  blues.00002.wav    1.034164          0.363637  161.499023
# 3           3  blues.00003.wav    0.071344          0.404785  172.265625
# 4           4  blues.00004.wav   -8.458839          0.308526  135.999178
#
#       pulse  flatness   contrast  zero_crossing  genre  genre_binary
# 0  0.274049  0.004498  20.526699          55031  blues             0
# 1  0.268452  0.002298  20.676128          37139  blues             0
# 2  0.264260  0.002631  22.197517          50563  blues             0
# 3  0.259775  0.000954  21.426268          22077  blues             0
# 4  0.213662  0.003238  21.466338          67225  blues             0

# %%
def prepare_data(ds):
    X_cols = ds[['mean_mfccs', 'mean_chroma_stft', 'tempo', 'pulse', 'flatness', 'contrast']].copy()
    
    X = X_cols.values
    X = X.reshape(len(X_cols),-1)
    
    #We add the dummy x_0
    poly = PolynomialFeatures(1)  
    X = poly.fit_transform(X)
    
    return X

# %%
X_clf = prepare_data(x_train)
X_clf_test = prepare_data(x_test)
print(X_clf)
# Out:
# [[ 1.00000000e+00  5.54844856e+00  4.88326818e-01 ...  2.61605173e-01
#    1.13055840e-01  1.57338472e+01]
#  [ 1.00000000e+00 -6.80238068e-01  4.05062348e-01 ...  2.06863061e-01
#    8.17304477e-03  2.11484983e+01]
#  [ 1.00000000e+00 -4.53672695e+00  2.92837381e-01 ...  2.38555655e-01
#    1.00252032e-02  2.27776324e+01]
#  ...
#  [ 1.00000000e+00 -4.57240963e+00  3.06965828e-01 ...  2.75139958e-01
#    7.87673239e-03  2.34719367e+01]
#  [ 1.00000000e+00  1.13126087e+00  3.56677800e-01 ...  2.70878077e-01
#    1.43560395e-02  2.23412517e+01]
#  [ 1.00000000e+00 -3.21365094e+00  2.57324815e-01 ...  2.21485987e-01
#    6.41589402e-04  2.14862664e+01]]

# %%
logreg = utils.fit_logreg(X_clf, y_train)

# %%
print('*************** Estimated parameters: ***********************')
print('[W_0,W] : [',logreg.intercept_,',', logreg.coef_, ']' )
# Out:
# *************** Estimated parameters: ***********************
# [W_0,W] : [ [2.64332436] , [[ 2.64332436e+00 -5.95947949e-02  5.85130909e+00 -2.37046488e-02
#   -1.70546881e+01  3.94528324e+02 -1.42877154e-01]] ]

# %%
def predict_and_test(model, X_test, y_test):
    '''
    Predicts using a model received as input and then evaluates the accuracy of the predicted data. 
    As inputs it receives the model, an input dataset X_test and the corresponding targets (ground thruth) y_test
    It returs the classification accuracy.
    '''
    y_hat = model.predict(X_test)
    print(y_hat)
    print(np.array(y_test))
    #Your code here
    correct = 0
    for i in range(len(y_hat)):
        if (y_hat[i] == np.array(y_test)[i]):
            compt = 1
        else :
            compt = 0
        correct += compt
    acc = correct / len(y_hat)
    
    return acc

# %%
acc = predict_and_test(logreg, X_clf, y_train)

print('*******************  Training accuracy (genre identification) ***************************')
print('ACC: ', acc)
print('*******************************************************************************************')
# Out:
# ['rock' 'rock' 'rock' 'blues' 'rock' 'rock' 'rock' 'blues' 'rock' 'rock'
#  'rock' 'rock' 'blues' 'blues' 'blues' 'rock' 'rock' 'rock' 'blues' 'rock'
#  'blues' 'rock' 'blues' 'rock' 'blues' 'rock' 'rock' 'blues' 'rock'
#  'blues' 'blues' 'rock' 'rock' 'blues' 'blues' 'rock' 'rock' 'blues'
#  'blues' 'blues' 'rock' 'rock' 'rock' 'blues' 'rock' 'blues' 'blues'
#  'rock' 'rock' 'blues' 'blues' 'rock' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'rock' 'blues' 'blues' 'rock' 'blues' 'rock' 'blues'
#  'rock' 'rock' 'rock' 'blues' 'blues' 'blues' 'rock' 'blues' 'rock'
#  'blues' 'rock' 'blues' 'blues' 'rock' 'blues' 'blues' 'rock' 'rock'
#  'rock' 'blues' 'rock' 'blues' 'blues' 'blues' 'blues' 'blues' 'rock'
#  'rock' 'rock' 'blues' 'rock' 'blues' 'rock' 'rock' 'blues' 'rock' 'blues'
#  'blues' 'rock' 'blues' 'blues' 'blues' 'blues' 'blues' 'rock' 'rock'
#  'blues' 'rock' 'blues' 'rock' 'blues' 'rock' 'blues' 'rock' 'blues'
#  'blues' 'rock' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'rock' 'blues' 'blues' 'blues' 'rock' 'blues' 'blues' 'blues' 'blues'
#  'rock' 'blues' 'rock' 'rock' 'rock' 'blues' 'rock' 'rock' 'rock' 'rock'
#  'rock' 'blues' 'blues' 'rock' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'rock' 'blues']
# ['rock' 'rock' 'blues' 'blues' 'rock' 'rock' 'rock' 'rock' 'rock' 'rock'
#  'rock' 'rock' 'blues' 'blues' 'blues' 'rock' 'rock' 'rock' 'blues' 'rock'
#  'blues' 'rock' 'blues' 'rock' 'blues' 'rock' 'rock' 'rock' 'rock' 'blues'
#  'blues' 'rock' 'blues' 'blues' 'rock' 'rock' 'rock' 'blues' 'blues'
#  'blues' 'rock' 'rock' 'rock' 'rock' 'rock' 'blues' 'blues' 'blues' 'rock'
#  'blues' 'blues' 'rock' 'rock' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'rock' 'blues' 'rock' 'rock' 'blues' 'blues' 'blues' 'rock' 'rock' 'rock'
#  'rock' 'rock' 'rock' 'rock' 'blues' 'rock' 'rock' 'rock' 'blues' 'rock'
#  'rock' 'blues' 'blues' 'rock' 'rock' 'blues' 'rock' 'rock' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'rock' 'rock' 'rock' 'blues' 'rock'
#  'blues' 'blues' 'rock' 'rock' 'rock' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'rock' 'rock' 'blues' 'rock' 'blues'
#  'rock' 'blues' 'blues' 'blues' 'rock' 'blues' 'rock' 'rock' 'blues'
#  'rock' 'blues' 'blues' 'blues' 'rock' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'rock' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'rock' 'rock' 'blues' 'rock' 'rock' 'rock' 'rock' 'rock' 'blues' 'rock'
#  'rock' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'rock' 'blues']
# *******************  Training accuracy (genre identification) ***************************
# ACC:  0.825
# *******************************************************************************************

# %%
def explore_thresholds(model, X, y, thresh):
    '''
    Computes accuracies by varying the cut-off threshold given a model, the input data and a range of thresholds. A ground truth needs to be provided
    to estimate the accuracy
    Works specifically for the Cleveland dataset.
    '''
    y_bool = (y == 'H')
    accs = [(np.sum(y_bool ==  ~(model.predict_proba(X)[:,0] >= t)) / len(y)) for t in thresh]
    
    return accs

# %%
# generate a range of thresholds from 0 to 1.
h=.02
x_min=0.0
x_max=1.0

thresh=np.arange(x_min, x_max, h)
accs = explore_thresholds(logreg, X_clf, y_train, thresh)
plt.rcParams['figure.figsize'] = [9.5, 6]
plt.scatter(thresh, accs)
plt.xlabel('Cut-off threshold')
plt.ylabel('Accuracy')
plt.title('Training accuracy as a function of the cut-off threshold')
plt.axvline(x=0.5,color='gray', linestyle='--') 
plt.show()

# %%
#If you chose a specific threshold value to use as cut-off replace 0.5 with your chosen value (or with any value)
custom_t = 0.4

# %%
print('******************  Testing accuracy *********************')
print('ACC: ', predict_and_test(logreg,X_clf_test, y_test))
print('*******************************************************************************************')

#If you chose a specific threshold value to use as cut-off this will be displayed
if custom_t != 0.5:
    print('*********  Testing accuracy with custom cut-off ***********')
    print('ACC: ',explore_thresholds(logreg, X_clf_test, y_test, [custom_t])[0])
    print('*******************************************************************************************')
# Out:
# ******************  Testing accuracy *********************
# ['blues' 'blues' 'rock' 'blues' 'rock' 'rock' 'rock' 'blues' 'blues'
#  'rock' 'rock' 'rock' 'blues' 'blues' 'rock' 'rock' 'blues' 'rock' 'blues'
#  'blues' 'rock' 'rock' 'rock' 'blues' 'blues' 'blues' 'blues' 'rock'
#  'rock' 'blues' 'rock' 'blues' 'rock' 'rock' 'rock' 'rock' 'rock' 'blues'
#  'rock' 'rock']
# ['rock' 'blues' 'blues' 'rock' 'rock' 'blues' 'rock' 'rock' 'rock' 'rock'
#  'rock' 'rock' 'blues' 'blues' 'blues' 'blues' 'blues' 'rock' 'blues'
#  'blues' 'rock' 'blues' 'rock' 'blues' 'blues' 'blues' 'rock' 'rock'
#  'rock' 'blues' 'rock' 'blues' 'rock' 'rock' 'rock' 'rock' 'blues' 'blues'
#  'rock' 'rock']
# ACC:  0.725
# *******************************************************************************************
# *********  Testing accuracy with custom cut-off ***********
# ACC:  0.5
# *******************************************************************************************

# %%
#importing our dataset and spliting into training and testing set

genres_df_all = pd.read_csv('../MusicGenreClassification/Music_data_set.csv')

x2 = genres_df_all.drop(['Unnamed: 0', 'song', 'genre'], axis=1)
y2 = genres_df_all['genre']

x_train2, x_test2, y_train2, y_test2 = train_test_split(x2, y2, test_size = 0.2, random_state = 27) 

print(genres_df_all.dtypes)     # Prints out the data types associated to each of the fields in the table
genres_df_all.head()
# Out:
# Unnamed: 0            int64
# song                 object
# mean_mfccs          float64
# mean_chroma_stft    float64
# tempo               float64
# pulse               float64
# flatness            float64
# contrast            float64
# zero_crossing         int64
# genre                object
# dtype: object
#    Unnamed: 0             song  mean_mfccs  mean_chroma_stft       tempo  \
# 0           0  blues.00000.wav    1.938016          0.350088  123.046875
# 1           1  blues.00001.wav   -0.055611          0.340914  107.666016
# 2           2  blues.00002.wav    1.034164          0.363637  161.499023
# 3           3  blues.00003.wav    0.071344          0.404785  172.265625
# 4           4  blues.00004.wav   -8.458839          0.308526  135.999178
#
#       pulse  flatness   contrast  zero_crossing  genre
# 0  0.274049  0.004498  20.526699          55031  blues
# 1  0.268452  0.002298  20.676128          37139  blues
# 2  0.264260  0.002631  22.197517          50563  blues
# 3  0.259775  0.000954  21.426268          22077  blues
# 4  0.213662  0.003238  21.466338          67225  blues

# %%
X_clf2 = prepare_data(x_train2)
X_clf_test2 = prepare_data(x_test2)
print(X_clf2)

logreg2 = utils.fit_logreg(X_clf2, y_train2)
# Out:
# [[ 1.00000000e+00 -8.87237072e+00  2.79348701e-01 ...  1.61485776e-01
#    1.73513219e-03  2.10026178e+01]
#  [ 1.00000000e+00 -1.37861598e+00  2.90966302e-01 ...  2.62671947e-01
#    1.27946688e-02  2.00832187e+01]
#  [ 1.00000000e+00  3.51899099e+00  4.72920150e-01 ...  1.88005611e-01
#    6.07267953e-02  1.84147952e+01]
#  ...
#  [ 1.00000000e+00 -1.71948071e+01  3.02542984e-01 ...  1.73864454e-01
#    6.61977287e-03  2.13391155e+01]
#  [ 1.00000000e+00  5.23638296e+00  5.18381894e-01 ...  2.10201874e-01
#    1.42971519e-02  2.06574969e+01]
#  [ 1.00000000e+00 -3.21365094e+00  2.57324815e-01 ...  2.21485987e-01
#    6.41589402e-04  2.14862664e+01]]
# C:\Users\yazid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
def dummy_model(X):
    '''
    Returns a zero (no disease) no matter the input
    '''
    return np.array(['blues']*(len(X)))

# %%
y_test_dummy = dummy_model(X_clf_test2)
acc_dummy = predict_and_test(logreg2, X_clf_test2, y_test_dummy)

acc_test = predict_and_test(logreg2, X_clf_test2, y_test2)
print('******************  Testing accuracy *********************')
print('ACC multinomial: ', acc_test)
print('ACC dummy: ', acc_dummy)
# Out:
# ['pop' 'pop' 'jazz' 'blues' 'hiphop' 'hiphop' 'jazz' 'pop' 'hiphop' 'pop'
#  'blues' 'metal' 'pop' 'pop' 'reggae' 'jazz' 'hiphop' 'blues' 'rock'
#  'classical' 'classical' 'reggae' 'classical' 'pop' 'reggae' 'country'
#  'disco' 'jazz' 'pop' 'pop' 'jazz' 'pop' 'blues' 'reggae' 'hiphop' 'jazz'
#  'blues' 'blues' 'country' 'classical' 'classical' 'country' 'blues'
#  'classical' 'pop' 'hiphop' 'disco' 'reggae' 'classical' 'blues' 'country'
#  'jazz' 'jazz' 'pop' 'blues' 'metal' 'jazz' 'pop' 'blues' 'classical'
#  'pop' 'metal' 'hiphop' 'jazz' 'pop' 'blues' 'hiphop' 'reggae' 'jazz'
#  'blues' 'pop' 'disco' 'hiphop' 'blues' 'jazz' 'metal' 'classical' 'pop'
#  'disco' 'metal' 'classical' 'reggae' 'classical' 'pop' 'country' 'pop'
#  'reggae' 'hiphop' 'disco' 'pop' 'metal' 'disco' 'hiphop' 'classical'
#  'blues' 'classical' 'pop' 'pop' 'classical' 'metal' 'metal' 'disco'
#  'jazz' 'jazz' 'classical' 'blues' 'blues' 'classical' 'pop' 'metal'
#  'metal' 'hiphop' 'jazz' 'classical' 'jazz' 'metal' 'pop' 'reggae'
#  'classical' 'pop' 'hiphop' 'classical' 'metal' 'blues' 'classical' 'pop'
#  'reggae' 'jazz' 'metal' 'classical' 'country' 'hiphop' 'classical'
#  'blues' 'metal' 'metal' 'jazz' 'pop' 'jazz' 'reggae' 'classical' 'reggae'
#  'classical' 'country' 'blues' 'pop' 'hiphop' 'pop' 'blues' 'pop'
#  'classical' 'pop' 'classical' 'disco' 'rock' 'jazz' 'jazz' 'classical'
#  'jazz' 'metal' 'pop' 'pop' 'jazz' 'pop' 'metal' 'pop' 'reggae' 'reggae'
#  'hiphop' 'pop' 'classical' 'metal' 'reggae' 'metal' 'blues' 'metal'
#  'hiphop' 'metal' 'country' 'classical' 'jazz' 'classical' 'pop'
#  'classical' 'classical' 'reggae' 'classical' 'hiphop' 'pop' 'reggae'
#  'hiphop' 'blues' 'pop' 'metal' 'reggae' 'pop' 'disco' 'pop' 'pop' 'jazz']
# ['blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues' 'blues'
#  'blues' 'blues']
# ['pop' 'pop' 'jazz' 'blues' 'hiphop' 'hiphop' 'jazz' 'pop' 'hiphop' 'pop'
#  'blues' 'metal' 'pop' 'pop' 'reggae' 'jazz' 'hiphop' 'blues' 'rock'
#  'classical' 'classical' 'reggae' 'classical' 'pop' 'reggae' 'country'
#  'disco' 'jazz' 'pop' 'pop' 'jazz' 'pop' 'blues' 'reggae' 'hiphop' 'jazz'
#  'blues' 'blues' 'country' 'classical' 'classical' 'country' 'blues'
#  'classical' 'pop' 'hiphop' 'disco' 'reggae' 'classical' 'blues' 'country'
#  'jazz' 'jazz' 'pop' 'blues' 'metal' 'jazz' 'pop' 'blues' 'classical'
#  'pop' 'metal' 'hiphop' 'jazz' 'pop' 'blues' 'hiphop' 'reggae' 'jazz'
#  'blues' 'pop' 'disco' 'hiphop' 'blues' 'jazz' 'metal' 'classical' 'pop'
#  'disco' 'metal' 'classical' 'reggae' 'classical' 'pop' 'country' 'pop'
#  'reggae' 'hiphop' 'disco' 'pop' 'metal' 'disco' 'hiphop' 'classical'
#  'blues' 'classical' 'pop' 'pop' 'classical' 'metal' 'metal' 'disco'
#  'jazz' 'jazz' 'classical' 'blues' 'blues' 'classical' 'pop' 'metal'
#  'metal' 'hiphop' 'jazz' 'classical' 'jazz' 'metal' 'pop' 'reggae'
#  'classical' 'pop' 'hiphop' 'classical' 'metal' 'blues' 'classical' 'pop'
#  'reggae' 'jazz' 'metal' 'classical' 'country' 'hiphop' 'classical'
#  'blues' 'metal' 'metal' 'jazz' 'pop' 'jazz' 'reggae' 'classical' 'reggae'
#  'classical' 'country' 'blues' 'pop' 'hiphop' 'pop' 'blues' 'pop'
#  'classical' 'pop' 'classical' 'disco' 'rock' 'jazz' 'jazz' 'classical'
#  'jazz' 'metal' 'pop' 'pop' 'jazz' 'pop' 'metal' 'pop' 'reggae' 'reggae'
#  'hiphop' 'pop' 'classical' 'metal' 'reggae' 'metal' 'blues' 'metal'
#  'hiphop' 'metal' 'country' 'classical' 'jazz' 'classical' 'pop'
#  'classical' 'classical' 'reggae' 'classical' 'hiphop' 'pop' 'reggae'
#  'hiphop' 'blues' 'pop' 'metal' 'reggae' 'pop' 'disco' 'pop' 'pop' 'jazz']
# ['pop' 'pop' 'blues' 'blues' 'hiphop' 'hiphop' 'pop' 'pop' 'hiphop' 'pop'
#  'country' 'metal' 'pop' 'jazz' 'hiphop' 'country' 'metal' 'blues'
#  'country' 'classical' 'classical' 'metal' 'classical' 'pop' 'blues'
#  'rock' 'reggae' 'classical' 'disco' 'disco' 'classical' 'pop' 'rock'
#  'reggae' 'hiphop' 'jazz' 'country' 'classical' 'blues' 'jazz' 'classical'
#  'country' 'country' 'classical' 'pop' 'hiphop' 'disco' 'reggae'
#  'classical' 'blues' 'rock' 'jazz' 'blues' 'pop' 'blues' 'metal' 'reggae'
#  'country' 'reggae' 'reggae' 'country' 'hiphop' 'rock' 'country' 'pop'
#  'blues' 'hiphop' 'metal' 'jazz' 'jazz' 'disco' 'rock' 'pop' 'blues'
#  'jazz' 'disco' 'classical' 'pop' 'rock' 'hiphop' 'classical' 'disco'
#  'classical' 'reggae' 'blues' 'disco' 'reggae' 'hiphop' 'hiphop' 'disco'
#  'metal' 'metal' 'country' 'classical' 'blues' 'classical' 'jazz' 'rock'
#  'country' 'metal' 'hiphop' 'reggae' 'jazz' 'rock' 'classical' 'blues'
#  'country' 'classical' 'country' 'rock' 'metal' 'pop' 'jazz' 'classical'
#  'jazz' 'hiphop' 'reggae' 'reggae' 'classical' 'rock' 'jazz' 'classical'
#  'disco' 'country' 'classical' 'classical' 'country' 'country' 'metal'
#  'classical' 'blues' 'pop' 'classical' 'blues' 'metal' 'metal' 'country'
#  'hiphop' 'jazz' 'country' 'classical' 'blues' 'classical' 'rock' 'rock'
#  'pop' 'blues' 'rock' 'country' 'hiphop' 'classical' 'pop' 'classical'
#  'disco' 'disco' 'rock' 'jazz' 'hiphop' 'jazz' 'metal' 'pop' 'disco'
#  'jazz' 'rock' 'hiphop' 'pop' 'rock' 'reggae' 'hiphop' 'disco' 'classical'
#  'metal' 'reggae' 'rock' 'jazz' 'metal' 'jazz' 'metal' 'blues' 'jazz'
#  'country' 'jazz' 'pop' 'rock' 'classical' 'blues' 'classical' 'hiphop'
#  'rock' 'rock' 'pop' 'classical' 'disco' 'metal' 'rock' 'hiphop' 'rock'
#  'pop' 'country' 'country']
# ******************  Testing accuracy *********************
# ACC multinomial:  0.47
# ACC dummy:  0.11
